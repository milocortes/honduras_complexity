# %%
## Cargamos paquetes 
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from py2cytoscape import util as cy 
from py2cytoscape import cytoscapejs as cyjs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 import matplotlib.pyplot as plt
#       6 from py2cytoscape import util as cy
# ----> 7 from py2cytoscape import cytoscapejs as cyjs
#
# File ~/Documents/egtp/iniciativas/honduras/.venv/lib/python3.13/site-packages/py2cytoscape/cytoscapejs/__init__.py:21
#      17     return display(Javascript(js_loader))
#      20 # Load Cytoscape.js and dependent libraries
# ---> 21 init()
#
# File ~/Documents/egtp/iniciativas/honduras/.venv/lib/python3.13/site-packages/py2cytoscape/cytoscapejs/__init__.py:13, in init()
#      12 def init():
# ---> 13     from IPython.core.display import display, Javascript
#      15     path = os.path.abspath(os.path.dirname(__file__)) + "/" + JS_LOADER_FILE
#      16     js_loader = open(path).read()
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (/home/milo/Documents/egtp/iniciativas/honduras/.venv/lib/python3.13/site-packages/IPython/core/display.py)
